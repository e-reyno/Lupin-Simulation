# %%
import openmc
import numpy as np
import neutronics_material_maker as nmm
import matplotlib.pyplot as plt
from math import cos, pi

# %%
#materials
#air
air = openmc.Material(name='air')
air.add_element("O",0.210748,'ao')
air.add_element("N",0.784431,'ao')
air.add_element("Ar",0.004671,'ao')
air.add_element("C", 0.00015,'ao')
air.set_density("g/cm3", 0.001205)

#ground surface - concrete
#ground_material = nmm.Material.from_library("concrete_heavy").openmc_material
ground_material = openmc.Material(name='ground_material')
ground_material.add_element("H" , 0.0052, 'ao')
ground_material.add_element("O",  0.3273, 'ao')
ground_material.add_element("C", 0.004, 'ao')
ground_material.add_element("Si", 0.0224, 'ao')
ground_material.add_element("Ca",  0.0657, 'ao')
ground_material.add_element("Mg", 0.0021, 'ao')
ground_material.add_element("Al", 0.0038, 'ao')
ground_material.add_element("Fe", 0.568, 'ao')
ground_material.add_element("P", 0.0015, 'ao')
ground_material.set_density("g/cm3", 3.6)
mats = openmc.Materials([ground_material, air])
mats.export_to_xml()

# %%
#ground surface
air_surface = openmc.model.RectangularParallelepiped(-50000, 50000, -10000, 10000, 0, 100000)
air_cell = openmc.Cell(region=-air_surface, fill=air)

ground_surface = openmc.model.RectangularParallelepiped(-50000, 50000, -10000, 10000, -1000, 0)
ground_cell = openmc.Cell(region=-ground_surface, fill=ground_material)

xmin = openmc.XPlane(x0=-50001, boundary_type = 'vacuum')
xmax = openmc.XPlane(x0=50001, boundary_type = 'vacuum')
ymin = openmc.YPlane(y0=-10001, boundary_type = 'vacuum')
ymax = openmc.YPlane(y0=10001, boundary_type = 'vacuum')
zmin = openmc.ZPlane(z0=-1001, boundary_type = 'vacuum')
zmax = openmc.ZPlane(z0=100001, boundary_type = 'vacuum')

void_region = +xmin & -xmax & -ymax & +ymin & +zmin & -zmax

void_cell =  openmc.Cell(region=void_region)

universe = openmc.Universe(cells=[air_cell, void_cell, ground_cell])
geom = openmc.Geometry(universe)
geom.export_to_xml()

color_assignment = {void_cell: 'blue', ground_cell: 'red', air:'purple'}
plt.show(universe.plot(width=(300100, 301100), basis='xz', colors=color_assignment))
plt.show(universe.plot(width=(101100, 101100), basis='xy', colors=color_assignment))
plt.show(universe.plot(width=(21100, 21100), basis='yz', colors=color_assignment))

# %%
def sim_sett(source_energy):
    #create the source
    sett = openmc.Settings()
    sett.particles = 500000
    sett.batches = 4
    sett.inactive = 0
    sett.run_mode = 'fixed source'

    source = openmc.Source()
    source.particle = 'neutron'
    source.energy = openmc.stats.Discrete([source_energy], [1])

    theta = np.rad2deg(np.arctan(50000/95000))
    print(theta)
    mu = openmc.stats.Uniform(cos(theta), 1.0)
    phi = openmc.stats.Uniform(0.0, 2*pi)
    source.angle  = openmc.stats.PolarAzimuthal(mu, phi, reference_uvw=(0, 0., 1))
    source.space = openmc.stats.Point((0,0,5000))
    sett.source = source
    sett.export_to_xml()
    return sett
# Out:
# 27.758540601060023

# %%
#mesh
air_mesh = openmc.RegularMesh(mesh_id=1, name="air_mesh")
air_mesh.dimension = [100,1,1]
air_mesh.lower_left = [-50000,-10000, 0]

air_mesh.upper_right = [50000,10000, 100]
mesh_filter = openmc.MeshFilter(air_mesh)
# Out:
# /usr/local/lib/python3.9/dist-packages/openmc/mixin.py:70: IDWarning: Another MeshBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %%
#tally
def create_tally():
    tallies = openmc.Tallies()
    shine_tally = openmc.Tally(name='shine_tally')
    neutron_filter = openmc.ParticleFilter(['neutron'])
    shine_tally.scores  = ['flux']
    shine_tally.filters = [mesh_filter, neutron_filter]
    tallies.append(shine_tally)
    tallies.export_to_xml()
    return tallies

# %%
energies = np.array([1e6, 2e6, 3e6, 4e6, 5e6, 8e6, 10e6, 12e6, 14e6, 16e6, 18e6, 19e6, 19.5e6])
energies
# Out:
# array([ 1000000.,  2000000.,  3000000.,  4000000.,  5000000.,  8000000.,
#        10000000., 12000000., 14000000., 16000000., 18000000., 19000000.,
#        19500000.])

# %%
df_list = []
for energy in energies:
    settings = sim_sett(energy)
    sim_tallies = create_tally()
    print(energy)
    model = openmc.model.Model(geom, mats, settings, sim_tallies)
    # !rm *.h5
    results_filename = model.run()
    
    results = openmc.StatePoint(results_filename)
    flux_tally = results.get_tally(name="shine_tally")
    df = flux_tally.get_pandas_dataframe()
    df_list.append(df)
    results.close()
# Out:
# 27.758540601060023
# 1000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:09:37
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4240e+00 seconds
#    Reading cross sections          = 1.4117e+00 seconds
#  Total time in simulation          = 7.6796e+01 seconds
#    Time in transport only          = 7.6765e+01 seconds
#    Time in active batches          = 7.6796e+01 seconds
#    Time accumulating tallies       = 2.3275e-02 seconds
#    Time writing statepoints        = 6.4821e-03 seconds
#  Total time for finalization       = 1.1743e-03 seconds
#  Total time elapsed                = 7.8225e+01 seconds
#  Calculation Rate (active)         = 26043.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.82506 +/- 0.00038
#
# 27.758540601060023
# 2000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:10:56
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.4753e+00 seconds
#    Reading cross sections          = 4.3710e+00 seconds
#  Total time in simulation          = 8.5189e+01 seconds
#    Time in transport only          = 8.5133e+01 seconds
#    Time in active batches          = 8.5189e+01 seconds
#    Time accumulating tallies       = 5.1517e-02 seconds
#    Time writing statepoints        = 4.5496e-03 seconds
#  Total time for finalization       = 4.5810e-04 seconds
#  Total time elapsed                = 8.9677e+01 seconds
#  Calculation Rate (active)         = 23477.1 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.80943 +/- 0.00030
#
# 27.758540601060023
# 3000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:12:27
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.5153e+00 seconds
#    Reading cross sections          = 4.4837e+00 seconds
#  Total time in simulation          = 8.3705e+00 seconds
#    Time in transport only          = 8.3327e+00 seconds
#    Time in active batches          = 8.3705e+00 seconds
#    Time accumulating tallies       = 2.1393e-02 seconds
#    Time writing statepoints        = 1.4016e-02 seconds
#  Total time for finalization       = 3.9470e-04 seconds
#  Total time elapsed                = 1.2896e+01 seconds
#  Calculation Rate (active)         = 238934 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.85282 +/- 0.00044
#
# 27.758540601060023
# 4000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:12:41
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0723e+00 seconds
#    Reading cross sections          = 4.9741e+00 seconds
#  Total time in simulation          = 4.5217e+01 seconds
#    Time in transport only          = 4.5196e+01 seconds
#    Time in active batches          = 4.5217e+01 seconds
#    Time accumulating tallies       = 1.2842e-02 seconds
#    Time writing statepoints        = 4.0386e-03 seconds
#  Total time for finalization       = 4.0660e-04 seconds
#  Total time elapsed                = 5.0301e+01 seconds
#  Calculation Rate (active)         = 44231.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.60799 +/- 0.00019
#
# 27.758540601060023
# 5000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:13:32
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4806e+00 seconds
#    Reading cross sections          = 1.4688e+00 seconds
#  Total time in simulation          = 4.8256e+00 seconds
#    Time in transport only          = 4.8169e+00 seconds
#    Time in active batches          = 4.8256e+00 seconds
#    Time accumulating tallies       = 2.9317e-03 seconds
#    Time writing statepoints        = 4.8557e-03 seconds
#  Total time for finalization       = 5.3640e-04 seconds
#  Total time elapsed                = 6.3111e+00 seconds
#  Calculation Rate (active)         = 414453 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.75870 +/- 0.00030
#
# 27.758540601060023
# 8000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:13:39
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.1515e+00 seconds
#    Reading cross sections          = 2.1289e+00 seconds
#  Total time in simulation          = 3.5940e+01 seconds
#    Time in transport only          = 3.5926e+01 seconds
#    Time in active batches          = 3.5940e+01 seconds
#    Time accumulating tallies       = 1.5250e-04 seconds
#    Time writing statepoints        = 1.3464e-02 seconds
#  Total time for finalization       = 3.5140e-04 seconds
#  Total time elapsed                = 3.8098e+01 seconds
#  Calculation Rate (active)         = 55647.8 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.67302 +/- 0.00047
#
# 27.758540601060023
# 10000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:14:18
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4324e+00 seconds
#    Reading cross sections          = 1.4207e+00 seconds
#  Total time in simulation          = 3.3255e+01 seconds
#    Time in transport only          = 3.3249e+01 seconds
#    Time in active batches          = 3.3255e+01 seconds
#    Time accumulating tallies       = 1.6990e-04 seconds
#    Time writing statepoints        = 4.6159e-03 seconds
#  Total time for finalization       = 4.2120e-04 seconds
#  Total time elapsed                = 3.4692e+01 seconds
#  Calculation Rate (active)         = 60141.7 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.65637 +/- 0.00045
#
# 27.758540601060023
# 12000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:14:54
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.5123e+00 seconds
#    Reading cross sections          = 1.4999e+00 seconds
#  Total time in simulation          = 5.2733e+00 seconds
#    Time in transport only          = 5.2675e+00 seconds
#    Time in active batches          = 5.2733e+00 seconds
#    Time accumulating tallies       = 2.3080e-04 seconds
#    Time writing statepoints        = 4.5063e-03 seconds
#  Total time for finalization       = 4.0620e-04 seconds
#  Total time elapsed                = 6.7906e+00 seconds
#  Calculation Rate (active)         = 379268 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.79724 +/- 0.00021
#
# 27.758540601060023
# 14000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:15:01
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.5306e+00 seconds
#    Reading cross sections          = 1.5188e+00 seconds
#  Total time in simulation          = 5.3316e+00 seconds
#    Time in transport only          = 5.3116e+00 seconds
#    Time in active batches          = 5.3316e+00 seconds
#    Time accumulating tallies       = 3.9850e-04 seconds
#    Time writing statepoints        = 1.7916e-02 seconds
#  Total time for finalization       = 6.0580e-04 seconds
#  Total time elapsed                = 6.8673e+00 seconds
#  Calculation Rate (active)         = 375124 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.81339 +/- 0.00036
#
# 27.758540601060023
# 16000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:15:09
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.5847e+00 seconds
#    Reading cross sections          = 1.5714e+00 seconds
#  Total time in simulation          = 5.4552e+00 seconds
#    Time in transport only          = 5.4493e+00 seconds
#    Time in active batches          = 5.4552e+00 seconds
#    Time accumulating tallies       = 1.7710e-04 seconds
#    Time writing statepoints        = 4.6280e-03 seconds
#  Total time for finalization       = 3.8840e-04 seconds
#  Total time elapsed                = 7.0459e+00 seconds
#  Calculation Rate (active)         = 366623 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.82769 +/- 0.00028
#
# 27.758540601060023
# 18000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:15:17
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4445e+00 seconds
#    Reading cross sections          = 1.4325e+00 seconds
#  Total time in simulation          = 4.3981e+01 seconds
#    Time in transport only          = 4.3974e+01 seconds
#    Time in active batches          = 4.3981e+01 seconds
#    Time accumulating tallies       = 1.9301e-03 seconds
#    Time writing statepoints        = 3.6544e-03 seconds
#  Total time for finalization       = 3.2100e-04 seconds
#  Total time elapsed                = 4.5430e+01 seconds
#  Calculation Rate (active)         = 45474.1 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.73201 +/- 0.00040
#
# 27.758540601060023
# 19000000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:16:03
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4881e+00 seconds
#    Reading cross sections          = 1.4660e+00 seconds
#  Total time in simulation          = 4.3903e+01 seconds
#    Time in transport only          = 4.3893e+01 seconds
#    Time in active batches          = 4.3903e+01 seconds
#    Time accumulating tallies       = 4.4072e-03 seconds
#    Time writing statepoints        = 4.2936e-03 seconds
#  Total time for finalization       = 3.7310e-04 seconds
#  Total time elapsed                = 4.5396e+01 seconds
#  Calculation Rate (active)         = 45555.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.74034 +/- 0.00044
#
# 27.758540601060023
# 19500000.0
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-21 14:16:49
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading O16 from /root/nndc_hdf5/O16.h5
#  Reading O17 from /root/nndc_hdf5/O17.h5
#  Reading N14 from /root/nndc_hdf5/N14.h5
#  Reading N15 from /root/nndc_hdf5/N15.h5
#  Reading Ar36 from /root/nndc_hdf5/Ar36.h5
#  WARNING: Negative value(s) found on probability table for nuclide Ar36 at 294K
#  Reading Ar38 from /root/nndc_hdf5/Ar38.h5
#  Reading Ar40 from /root/nndc_hdf5/Ar40.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading Si28 from /root/nndc_hdf5/Si28.h5
#  Reading Si29 from /root/nndc_hdf5/Si29.h5
#  Reading Si30 from /root/nndc_hdf5/Si30.h5
#  Reading Ca40 from /root/nndc_hdf5/Ca40.h5
#  Reading Ca42 from /root/nndc_hdf5/Ca42.h5
#  Reading Ca43 from /root/nndc_hdf5/Ca43.h5
#  Reading Ca44 from /root/nndc_hdf5/Ca44.h5
#  Reading Ca46 from /root/nndc_hdf5/Ca46.h5
#  Reading Ca48 from /root/nndc_hdf5/Ca48.h5
#  Reading Mg24 from /root/nndc_hdf5/Mg24.h5
#  Reading Mg25 from /root/nndc_hdf5/Mg25.h5
#  Reading Mg26 from /root/nndc_hdf5/Mg26.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Fe54 from /root/nndc_hdf5/Fe54.h5
#  Reading Fe56 from /root/nndc_hdf5/Fe56.h5
#  Reading Fe57 from /root/nndc_hdf5/Fe57.h5
#  Reading Fe58 from /root/nndc_hdf5/Fe58.h5
#  Reading P31 from /root/nndc_hdf5/P31.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for O17
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Creating state point statepoint.4.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4709e+00 seconds
#    Reading cross sections          = 1.4591e+00 seconds
#  Total time in simulation          = 4.6797e+01 seconds
#    Time in transport only          = 4.6788e+01 seconds
#    Time in active batches          = 4.6797e+01 seconds
#    Time accumulating tallies       = 3.0195e-03 seconds
#    Time writing statepoints        = 5.0575e-03 seconds
#  Total time for finalization       = 4.7310e-04 seconds
#  Total time elapsed                = 4.8273e+01 seconds
#  Calculation Rate (active)         = 42737.7 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.74378 +/- 0.00055

# %%
distance_x = air_mesh.vertices[:,0,0,0]
for i, energy in enumerate(energies):
    df_list[i]["Energies"] = energy

# %%
for df in df_list[:]:
    flux = df[df['score'] == 'flux']
    flux_mean = flux["mean"]
    flux_std = flux["std. dev."]
    plt.errorbar(distance_x[:-1]/100, flux_mean, flux_std, label=(str(df["Energies"][0]/10**6)+ " MeV"), marker='x')
    plt.legend()
    plt.xlabel("Distance in x-direction from Source (m)")
    plt.ylabel("Flux: Particle/Source Particle $cm^2$")
    plt.axvline(x=0, ls='--', color='black')
    plt.xlim(-1,200)
    #plt.ylim(3,8.5)
    #plt.xscale('log')
    #plt.yscale('log')

# %%
#plot flux as function of energy
flux_array = np.array(flux_list)
flux_array
np.max(df_list[0]["mean"])
# Out:
# 11.764576288280704

# %%
flux_array[:,50]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [258], line 1
# ----> 1 flux_array[:,50]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
plt.loglog(energies, flux_array, color='b', ls=None, marker='x')
plt.xlabel("Energy (MeV)")
plt.ylabel("Flux p/sp cm2")
plt.title("Flux as function of energy of neutron for peak fluence")
