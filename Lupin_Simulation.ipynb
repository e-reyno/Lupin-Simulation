# %%
import openmc
import matplotlib.pyplot as plt
import numpy as np
import openmc_source_plotter
import neutronics_material_maker as nmm
import openmc_source_plotter

# %%
#Lupin materials

#lead casing
lead = openmc.Material(name='lead')
lead.add_element('Pb', 1, 'ao')
#aluminium shell
al = openmc.Material(name='aluminium')
al.add_element('Al', 1, 'ao')
#cadmium 
cadmium = openmc.Material(name='cadmium')
cadmium.add_element('Cd', 1, 'ao')
#BF3
bf3 = nmm.Material.from_library('Boron Fluoride (BF3)').openmc_material
#polyethylene
polyethylene = openmc.Material(name='polyethylene')
polyethylene.add_elements_from_formula('C2H4')
polyethylene.set_density('kg/m3',940)

#polyethylene.add_s_alpha_beta('c_H_in_CH2')


materials = openmc.Materials([lead, al, cadmium, bf3, polyethylene])
materials.export_to_xml()

# %%
#geometry dimensions
cylinder_radius = 0.054
detector_radius = 0.02
outer_cylinder_radius = 0.125
lead_thickness = 0.0015
shielding_thickness = 0.0015

lead_height = 0.141
b_detector_height = 0.047
cylinder_height = 0.297
big_cd_height = 0.05
small_cd_height = 0.025

cd_thickness = 0.0015
cd_gap = 0.02425

# %%
#geometry model

detector = openmc.ZCylinder(r=detector_radius)
shielding = openmc.ZCylinder(r=detector_radius + shielding_thickness)
inner_cylinder = openmc.ZCylinder(r=cylinder_radius)
lead_plate = openmc.ZCylinder(r=cylinder_radius + lead_thickness)
cd_cylinder = openmc.ZCylinder(r=cylinder_radius - (cd_thickness))
outer_cylinder = openmc.ZCylinder(r=outer_cylinder_radius)
source_sphere = openmc.Sphere(r=0.5)
outer_void = openmc.Sphere(r=0.55, boundary_type='vacuum')

top_cylinder = openmc.ZPlane(z0=0.5*cylinder_height)
bottom_cylinder = openmc.ZPlane(z0=-0.5*cylinder_height)
bottom_detector = openmc.ZPlane(z0=-0.5*cylinder_height + b_detector_height)
bottom_shielding = openmc.ZPlane(z0=-0.5*cylinder_height + b_detector_height-shielding_thickness)
top_lead = openmc.ZPlane(z0=0.5*lead_height)
bottom_lead = openmc.ZPlane(z0=-0.5*lead_height)
top_wall_cylinder = openmc.ZPlane(z0=0.5*cylinder_height+0.001)

cd_cylinder_region = +cd_cylinder & -inner_cylinder 
cd_bottom_1 = openmc.ZPlane(0.5*cylinder_height-big_cd_height)
cd_top_2 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap)
cd_bottom_2 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap-small_cd_height)
cd_top_3 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap-small_cd_height-cd_gap)
cd_bottom_3 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap-small_cd_height-cd_gap-big_cd_height)
cd_top_4 = openmc.ZPlane(0.5*-cylinder_height+big_cd_height+cd_gap+small_cd_height)
cd_bottom_4 = openmc.ZPlane(0.5*-cylinder_height+big_cd_height+cd_gap)
cd_top_5 = openmc.ZPlane(0.5*-cylinder_height+big_cd_height)

cd_1 = cd_cylinder_region & -top_cylinder & +cd_bottom_1
cd_2 = cd_cylinder_region & -cd_top_2 & +cd_bottom_2
cd_3 = cd_cylinder_region & -cd_top_3 & +cd_bottom_3
cd_4 = cd_cylinder_region & -cd_top_4 & +cd_bottom_4
cd_5 = cd_cylinder_region & -cd_top_5 & +bottom_cylinder
cd_region = cd_1 | cd_2 | cd_3 | cd_4 | cd_5

detector_region = -detector & -top_cylinder & +bottom_detector
shielding_region = (-shielding & -top_cylinder & +bottom_shielding & +detector) | ( -detector & +bottom_shielding & -bottom_detector)

inner_polyethylene_region = ((-inner_cylinder & + shielding & -top_cylinder & +bottom_cylinder) | (-shielding & -bottom_shielding & +bottom_cylinder)) & ~cd_region

lead_region = -lead_plate & -top_lead & +bottom_lead & + inner_cylinder
outer_polyethylene_region = (-outer_cylinder & -top_cylinder & +bottom_cylinder & ~lead_region & +inner_cylinder ) | (-top_wall_cylinder & +top_cylinder & - outer_cylinder)
sphere_region = (-source_sphere & +outer_cylinder) | (+top_wall_cylinder & -source_sphere) | (-bottom_cylinder & -source_sphere)
outer_void_region = +source_sphere & -outer_void

detector_cell = openmc.Cell(region=detector_region, fill=bf3)
shielding_cell = openmc.Cell(region=shielding_region, fill=al)
inner_polyethylene_cell = openmc.Cell(region=inner_polyethylene_region, fill=polyethylene)
lead_cell = openmc.Cell(region=lead_region, fill=lead)
cd_cell = openmc.Cell(region =cd_region, fill = cadmium)
outer_polyethylene_cell = openmc.Cell(region=outer_polyethylene_region, fill=polyethylene)
source_cell = openmc.Cell(region=sphere_region)
outer_void_cell = openmc.Cell(region=outer_void_region)

universe = openmc.universe = openmc.Universe(cells=[detector_cell, shielding_cell, inner_polyethylene_cell, lead_cell, cd_cell, outer_polyethylene_cell, source_cell, outer_void_cell])


x,y = 0.2,0.2
color_assignment = {detector_cell : 'blue',
                    shielding_cell : 'red',
                    inner_polyethylene_cell : 'green',
                    cd_cell : 'orange',
                    lead_cell : 'grey',
                    outer_polyethylene_cell :'limegreen',
                   source_cell : 'black'}
#plt.show(universe.plot(width=(x, y), basis='xz',  colors=color_assignment))
#plt.show(universe.plot(width=(x, y), basis='xy',  colors=color_assignment))
#plt.show(universe.plot(width=(x, y), basis='yz',  colors=color_assignment))

geometry = openmc.Geometry(universe)
geometry.export_to_xml()

# %%
# makes the 3d "cube" style geometry
vox_plot = openmc.Plot()
vox_plot.type = 'voxel'
vox_plot.width = (1,1,1)
vox_plot.pixels = (300,300,300)
vox_plot.filename = 'plot_lupin'
vox_plot.color_by = 'material'
# vox_plot.colors = {copper: 'blue'}  # materials can be coloured using this command
plots = openmc.Plots([vox_plot])
plots.export_to_xml()

openmc.plot_geometry()
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:18
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 4
# Plot file: plot_lupin.h5
# Universe depth: -1
# Plot Type: Voxel
# Origin: 0 0 0
# Width:    1    1    1
# Coloring: Materials
# Voxels: 300 300 300
#
#  Processing plot 4: plot_lupin.h5...

# %%
energies = np.linspace(0.0001,18e6, 50)

# %%
#now create the source
#spherical source enclosing the detector
def sett_func(source_energy):
    
    sett = openmc.Settings()
    sett.particles = 10000
    sett.batches = 5
    sett.inactive = 0
    sett.run_mode = 'fixed source'

    sphere_source = openmc.Source()

    phi_angle = openmc.stats.Uniform(a=0., b= 2*3.14159265359)
    costheta_angle = openmc.stats.Uniform(a=-1, b=1)
    source_distance = openmc.stats.Discrete([-0.5, 0.5], [0.5,0.5]) #m away from the lupin detector

    sphere_source.particle = 'neutron'
    sphere_source.energy = openmc.stats.Discrete([source_energy],[1])
    sphere_source.angle = openmc.stats.Isotropic()
    sphere_source.space = openmc.stats.SphericalIndependent(source_distance, costheta_angle, phi_angle, origin=(0.0, 0.0, 0.0))
    sett.source = sphere_source
    return sett

# %%
#now create a tally to calibrate the detector
def tallies_func():
    tallies = openmc.Tallies()
    neutron_particle_filter = openmc.ParticleFilter(['neutron'])
    energies = np.linspace(0,15e6, 300)
    energy_filter = openmc.EnergyFilter(energies)
    detector_cell_filter = openmc.CellFilter(detector_cell)
    detector_tally = openmc.Tally(name='detector_tally')
    detector_tally.scores = ['flux']
    detector_tally.filters = [detector_cell_filter, neutron_particle_filter, energy_filter]
    tallies.append(detector_tally)
    #inelastic (n,alpha) reaction between neutrons and 10B
    detector_n_alpha_tally = openmc.Tally(name='detector_n_alpha_tally')
    detector_n_alpha_tally.scores = ['(n,a)']
    detector_n_alpha_tally.filters = [detector_cell_filter, neutron_particle_filter]

    tallies.append(detector_n_alpha_tally)
    return tallies
tallies = tallies_func()

# %%
nalpha_tallies = []
fluxes = []
for energy in energies:
    sett = sett_func(energy)
    model = openmc.model.Model(geometry, materials, sett, tallies)
    # remove old files and runs OpenMC
    # !rm *.h5
    results_filename = model.run()
    results = openmc.StatePoint(results_filename)
    n_alpha_tally = results.get_tally(name="detector_n_alpha_tally")
    flux_tally = results.get_tally(name="detector_tally")
    nalpha_tallies.append(n_alpha_tally.mean.ravel())
    fluxes.append(flux_tally.get_pandas_dataframe())
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:24
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.2337e-01 seconds
#    Reading cross sections          = 9.0520e-01 seconds
#  Total time in simulation          = 5.7831e-02 seconds
#    Time in transport only          = 5.0221e-02 seconds
#    Time in active batches          = 5.7831e-02 seconds
#    Time accumulating tallies       = 1.9169e-03 seconds
#    Time writing statepoints        = 5.2299e-03 seconds
#  Total time for finalization       = 1.0944e-03 seconds
#  Total time elapsed                = 9.8772e-01 seconds
#  Calculation Rate (active)         = 864591 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99460 +/- 0.00019
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:26
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.6903e-01 seconds
#    Reading cross sections          = 9.5470e-01 seconds
#  Total time in simulation          = 9.0481e-02 seconds
#    Time in transport only          = 6.5179e-02 seconds
#    Time in active batches          = 9.0481e-02 seconds
#    Time accumulating tallies       = 1.9027e-02 seconds
#    Time writing statepoints        = 5.7266e-03 seconds
#  Total time for finalization       = 5.7480e-04 seconds
#  Total time elapsed                = 1.0641e+00 seconds
#  Calculation Rate (active)         = 552600 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:28
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1398e+00 seconds
#    Reading cross sections          = 1.1203e+00 seconds
#  Total time in simulation          = 1.0982e-01 seconds
#    Time in transport only          = 7.2407e-02 seconds
#    Time in active batches          = 1.0982e-01 seconds
#    Time accumulating tallies       = 3.1570e-02 seconds
#    Time writing statepoints        = 5.1720e-03 seconds
#  Total time for finalization       = 6.5130e-04 seconds
#  Total time elapsed                = 1.2564e+00 seconds
#  Calculation Rate (active)         = 455308 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:30
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1688e+00 seconds
#    Reading cross sections          = 1.1490e+00 seconds
#  Total time in simulation          = 1.2704e-01 seconds
#    Time in transport only          = 8.3520e-02 seconds
#    Time in active batches          = 1.2704e-01 seconds
#    Time accumulating tallies       = 3.6913e-02 seconds
#    Time writing statepoints        = 5.9081e-03 seconds
#  Total time for finalization       = 1.2032e-03 seconds
#  Total time elapsed                = 1.3022e+00 seconds
#  Calculation Rate (active)         = 393586 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:33
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2994e+00 seconds
#    Reading cross sections          = 1.2786e+00 seconds
#  Total time in simulation          = 8.5328e-02 seconds
#    Time in transport only          = 6.5304e-02 seconds
#    Time in active batches          = 8.5328e-02 seconds
#    Time accumulating tallies       = 1.4927e-02 seconds
#    Time writing statepoints        = 4.6295e-03 seconds
#  Total time for finalization       = 6.7110e-04 seconds
#  Total time elapsed                = 1.3907e+00 seconds
#  Calculation Rate (active)         = 585973 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:35
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.6944e-01 seconds
#    Reading cross sections          = 9.5021e-01 seconds
#  Total time in simulation          = 9.9999e-02 seconds
#    Time in transport only          = 7.2764e-02 seconds
#    Time in active batches          = 9.9999e-02 seconds
#    Time accumulating tallies       = 1.9832e-02 seconds
#    Time writing statepoints        = 4.6746e-03 seconds
#  Total time for finalization       = 1.0959e-03 seconds
#  Total time elapsed                = 1.0754e+00 seconds
#  Calculation Rate (active)         = 500005 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:37
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.7904e+00 seconds
#    Reading cross sections          = 1.7626e+00 seconds
#  Total time in simulation          = 1.4030e-01 seconds
#    Time in transport only          = 8.4670e-02 seconds
#    Time in active batches          = 1.4030e-01 seconds
#    Time accumulating tallies       = 4.8485e-02 seconds
#    Time writing statepoints        = 5.9923e-03 seconds
#  Total time for finalization       = 8.3310e-04 seconds
#  Total time elapsed                = 1.9383e+00 seconds
#  Calculation Rate (active)         = 356375 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:40
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3761e+00 seconds
#    Reading cross sections          = 1.3512e+00 seconds
#  Total time in simulation          = 1.4810e-01 seconds
#    Time in transport only          = 1.0485e-01 seconds
#    Time in active batches          = 1.4810e-01 seconds
#    Time accumulating tallies       = 3.3850e-02 seconds
#    Time writing statepoints        = 8.0140e-03 seconds
#  Total time for finalization       = 9.6850e-04 seconds
#  Total time elapsed                = 1.5309e+00 seconds
#  Calculation Rate (active)         = 337599 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:42
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3768e+00 seconds
#    Reading cross sections          = 1.3428e+00 seconds
#  Total time in simulation          = 2.0652e-01 seconds
#    Time in transport only          = 1.3690e-01 seconds
#    Time in active batches          = 2.0652e-01 seconds
#    Time accumulating tallies       = 6.2114e-02 seconds
#    Time writing statepoints        = 6.9081e-03 seconds
#  Total time for finalization       = 1.0593e-03 seconds
#  Total time elapsed                = 1.5921e+00 seconds
#  Calculation Rate (active)         = 242105 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:45
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2393e+00 seconds
#    Reading cross sections          = 1.2127e+00 seconds
#  Total time in simulation          = 1.2909e-01 seconds
#    Time in transport only          = 8.8596e-02 seconds
#    Time in active batches          = 1.2909e-01 seconds
#    Time accumulating tallies       = 3.2618e-02 seconds
#    Time writing statepoints        = 7.3703e-03 seconds
#  Total time for finalization       = 1.3181e-03 seconds
#  Total time elapsed                = 1.3763e+00 seconds
#  Calculation Rate (active)         = 387331 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:10:48
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.5735e+00 seconds
#    Reading cross sections          = 1.5556e+00 seconds
#  Total time in simulation          = 1.0374e-01 seconds
#    Time in transport only          = 7.2545e-02 seconds
#    Time in active batches          = 1.0374e-01 seconds
#    Time accumulating tallies       = 2.4990e-02 seconds
#    Time writing statepoints        = 4.4630e-03 seconds
#  Total time for finalization       = 1.5129e-03 seconds
#  Total time elapsed                = 1.6842e+00 seconds
#  Calculation Rate (active)         = 481995 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
# ...
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:12:07
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1352e+00 seconds
#    Reading cross sections          = 1.1050e+00 seconds
#  Total time in simulation          = 9.2452e-02 seconds
#    Time in transport only          = 7.0428e-02 seconds
#    Time in active batches          = 9.2452e-02 seconds
#    Time accumulating tallies       = 1.6492e-02 seconds
#    Time writing statepoints        = 4.9834e-03 seconds
#  Total time for finalization       = 7.0410e-04 seconds
#  Total time elapsed                = 1.2346e+00 seconds
#  Calculation Rate (active)         = 540823 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00006 +/- 0.00005
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:12:09
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0195e+00 seconds
#    Reading cross sections          = 1.0062e+00 seconds
#  Total time in simulation          = 5.2901e-02 seconds
#    Time in transport only          = 4.8161e-02 seconds
#    Time in active batches          = 5.2901e-02 seconds
#    Time accumulating tallies       = 9.3700e-05 seconds
#    Time writing statepoints        = 4.3036e-03 seconds
#  Total time for finalization       = 6.0270e-04 seconds
#  Total time elapsed                = 1.0778e+00 seconds
#  Calculation Rate (active)         = 945158 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00006 +/- 0.00005
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:12:11
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2622e+00 seconds
#    Reading cross sections          = 1.2398e+00 seconds
#  Total time in simulation          = 1.9342e-01 seconds
#    Time in transport only          = 1.2476e-01 seconds
#    Time in active batches          = 1.9342e-01 seconds
#    Time accumulating tallies       = 6.2782e-02 seconds
#    Time writing statepoints        = 5.0664e-03 seconds
#  Total time for finalization       = 7.5310e-04 seconds
#  Total time elapsed                = 1.4643e+00 seconds
#  Calculation Rate (active)         = 258501 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00006 +/- 0.00005
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.14.0-dev
#         Git SHA1 | bdb6d38bfdfdf640785cefd0db618d242f55962e
#        Date/Time | 2022-10-06 14:12:13
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /nuclear_data/ENDFB-7.1-NNDC_Pb204.h5
#  Reading Pb206 from /nuclear_data/ENDFB-7.1-NNDC_Pb206.h5
#  Reading Pb207 from /nuclear_data/ENDFB-7.1-NNDC_Pb207.h5
#  Reading Pb208 from /nuclear_data/ENDFB-7.1-NNDC_Pb208.h5
#  Reading Al27 from /nuclear_data/ENDFB-7.1-NNDC_Al27.h5
#  Reading Cd106 from /nuclear_data/ENDFB-7.1-NNDC_Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /nuclear_data/ENDFB-7.1-NNDC_Cd108.h5
#  Reading Cd110 from /nuclear_data/ENDFB-7.1-NNDC_Cd110.h5
#  Reading Cd111 from /nuclear_data/ENDFB-7.1-NNDC_Cd111.h5
#  Reading Cd112 from /nuclear_data/ENDFB-7.1-NNDC_Cd112.h5
#  Reading Cd113 from /nuclear_data/ENDFB-7.1-NNDC_Cd113.h5
#  Reading Cd114 from /nuclear_data/ENDFB-7.1-NNDC_Cd114.h5
#  Reading Cd116 from /nuclear_data/ENDFB-7.1-NNDC_Cd116.h5
#  Reading B10 from /nuclear_data/ENDFB-7.1-NNDC_B10.h5
#  Reading B11 from /nuclear_data/ENDFB-7.1-NNDC_B11.h5
#  Reading F19 from /nuclear_data/ENDFB-7.1-NNDC_F19.h5
#  Reading C12 from /nuclear_data/TENDL-2019_C12.h5
#  Reading C13 from /nuclear_data/TENDL-2019_C13.h5
#  Reading H1 from /nuclear_data/ENDFB-7.1-NNDC_H1.h5
#  Reading H2 from /nuclear_data/ENDFB-7.1-NNDC_H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.8165e-01 seconds
#    Reading cross sections          = 9.6719e-01 seconds
#  Total time in simulation          = 4.3834e-02 seconds
#    Time in transport only          = 4.0025e-02 seconds
#    Time in active batches          = 4.3834e-02 seconds
#    Time accumulating tallies       = 3.7000e-05 seconds
#    Time writing statepoints        = 3.5631e-03 seconds
#  Total time for finalization       = 6.1340e-04 seconds
#  Total time elapsed                = 1.0307e+00 seconds
#  Calculation Rate (active)         = 1.14065e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00008 +/- 0.00006

# %%
norm_counts = nalpha_tallies[1:] 


plt.semilogx(energies[1:]/10**6, norm_counts, color='r')
plt.ylabel(r'(n, $\alpha $) reaction rate per particle')
plt.xlabel("Energy (MeV)")
plt.show()

# %%
#normalise reaction rate
volume = b_detector_height * (detector_radius**2*np.pi)
print(volume*10**6)
bf3_density = 7.3*10**-4 #atoms/b cm
# Out:
# 59.06194188748811
