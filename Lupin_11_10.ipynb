# %%
import openmc
import matplotlib.pyplot as plt
import numpy as np
import openmc_source_plotter
import neutronics_material_maker as nmm
import openmc_source_plotter

# %%
import os
print(os.environ["OPENMC_CROSS_SECTIONS"])
# Out:
# /root/nndc_hdf5/cross_sections.xml

# %%
#Lupin materials

#lead casing
lead = openmc.Material(name='lead')
lead.add_element('Pb', 1, 'ao')
#aluminium shell
al = openmc.Material(name='aluminium')
al.add_element('Al', 1, 'ao')
al.add_s_alpha_beta("c_Al27")
#cadmium 
cadmium = openmc.Material(name='cadmium')
cadmium.add_element('Cd', 1, 'ao')
#BF3
bf3 = nmm.Material.from_library('Boron Fluoride (BF3)', pressure=26664).openmc_material
#polyethylene
polyethylene = openmc.Material(name='polyethylene')
polyethylene.add_elements_from_formula('C2H4')
polyethylene.set_density('g/cm3',0.93)
polyethylene.add_s_alpha_beta('c_H_in_CH2')


materials = openmc.Materials([lead, al, cadmium, bf3, polyethylene])
materials.export_to_xml()

# %%
#geometry dimensions
cylinder_radius = 0.054
detector_radius = 0.02
outer_cylinder_radius = 0.125
lead_thickness = 0.0015
shielding_thickness = 0.0015

lead_height = 0.141
b_detector_height = 0.047
cylinder_height = 0.297
big_cd_height = 0.05
small_cd_height = 0.025

cd_thickness = 0.0015
cd_gap = 0.02425

# %%
#geometry model

detector = openmc.ZCylinder(r=detector_radius)
shielding = openmc.ZCylinder(r=detector_radius + shielding_thickness)
inner_cylinder = openmc.ZCylinder(r=cylinder_radius)
lead_plate = openmc.ZCylinder(r=cylinder_radius + lead_thickness)
cd_cylinder = openmc.ZCylinder(r=cylinder_radius - (cd_thickness))
outer_cylinder = openmc.ZCylinder(r=outer_cylinder_radius)
source_sphere = openmc.Sphere(r=0.5)
outer_void = openmc.Sphere(r=0.55, boundary_type='vacuum')

top_cylinder = openmc.ZPlane(z0=0.5*cylinder_height)
bottom_cylinder = openmc.ZPlane(z0=-0.5*cylinder_height)
bottom_detector = openmc.ZPlane(z0=-0.5*cylinder_height + b_detector_height)
bottom_shielding = openmc.ZPlane(z0=-0.5*cylinder_height + b_detector_height-shielding_thickness)
top_lead = openmc.ZPlane(z0=0.5*lead_height)
bottom_lead = openmc.ZPlane(z0=-0.5*lead_height)
top_wall_cylinder = openmc.ZPlane(z0=0.5*cylinder_height+0.001)

cd_cylinder_region = +cd_cylinder & -inner_cylinder 
cd_bottom_1 = openmc.ZPlane(0.5*cylinder_height-big_cd_height)
cd_top_2 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap)
cd_bottom_2 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap-small_cd_height)
cd_top_3 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap-small_cd_height-cd_gap)
cd_bottom_3 = openmc.ZPlane(0.5*cylinder_height-big_cd_height-cd_gap-small_cd_height-cd_gap-big_cd_height)
cd_top_4 = openmc.ZPlane(0.5*-cylinder_height+big_cd_height+cd_gap+small_cd_height)
cd_bottom_4 = openmc.ZPlane(0.5*-cylinder_height+big_cd_height+cd_gap)
cd_top_5 = openmc.ZPlane(0.5*-cylinder_height+big_cd_height)

cd_1 = cd_cylinder_region & -top_cylinder & +cd_bottom_1
cd_2 = cd_cylinder_region & -cd_top_2 & +cd_bottom_2
cd_3 = cd_cylinder_region & -cd_top_3 & +cd_bottom_3
cd_4 = cd_cylinder_region & -cd_top_4 & +cd_bottom_4
cd_5 = cd_cylinder_region & -cd_top_5 & +bottom_cylinder
cd_region = cd_1 | cd_2 | cd_3 | cd_4 | cd_5

detector_region = -detector & -top_cylinder & +bottom_detector
shielding_region = (-shielding & -top_cylinder & +bottom_shielding & +detector) | ( -detector & +bottom_shielding & -bottom_detector)

inner_polyethylene_region = ((-inner_cylinder & + shielding & -top_cylinder & +bottom_cylinder) | (-shielding & -bottom_shielding & +bottom_cylinder)) & ~cd_region

lead_region = -lead_plate & -top_lead & +bottom_lead & + inner_cylinder
outer_polyethylene_region = (-outer_cylinder & -top_cylinder & +bottom_cylinder & ~lead_region & +inner_cylinder ) | (-top_wall_cylinder & +top_cylinder & - outer_cylinder)
sphere_region = (-source_sphere & +outer_cylinder) | (+top_wall_cylinder & -source_sphere) | (-bottom_cylinder & -source_sphere)
outer_void_region = +source_sphere & -outer_void

detector_cell = openmc.Cell(region=detector_region, fill=bf3)
shielding_cell = openmc.Cell(region=shielding_region, fill=al)
inner_polyethylene_cell = openmc.Cell(region=inner_polyethylene_region, fill=polyethylene)
lead_cell = openmc.Cell(region=lead_region, fill=lead)
cd_cell = openmc.Cell(region =cd_region, fill = cadmium)
outer_polyethylene_cell = openmc.Cell(region=outer_polyethylene_region, fill=polyethylene)
source_cell = openmc.Cell(region=sphere_region)
outer_void_cell = openmc.Cell(region=outer_void_region)

universe = openmc.universe = openmc.Universe(cells=[detector_cell, shielding_cell, inner_polyethylene_cell, lead_cell, cd_cell, outer_polyethylene_cell, source_cell, outer_void_cell])


x,y = 0.2,0.2
color_assignment = {detector_cell : 'blue',
                    shielding_cell : 'red',
                    inner_polyethylene_cell : 'green',
                    cd_cell : 'orange',
                    lead_cell : 'grey',
                    outer_polyethylene_cell :'limegreen',
                   source_cell : 'black'}
plt.show(universe.plot(width=(x, y), basis='xz',  colors=color_assignment))
#plt.show(universe.plot(width=(x, y), basis='xy',  colors=color_assignment))
#plt.show(universe.plot(width=(x, y), basis='yz',  colors=color_assignment))

geometry = openmc.Geometry(universe)
geometry.export_to_xml()

# %%
#now create the source
#spherical source enclosing the detector
def sett_func(source_energy):
    
    sett = openmc.Settings()
    sett.particles = 1000000
    sett.batches = 5
    sett.inactive = 0
    sett.run_mode = 'fixed source'

    sphere_source = openmc.Source()

    phi_angle = openmc.stats.Uniform(a=0., b= 2*3.14159265359)
    costheta_angle = openmc.stats.Uniform(a=-1, b=1)
    source_distance = openmc.stats.Discrete([-0.5, 0.5], [0.5,0.5]) #m away from the lupin detector

    sphere_source.particle = 'neutron'
    sphere_source.energy = openmc.stats.Discrete([source_energy],[1])
    sphere_source.angle = openmc.stats.Isotropic()
    sphere_source.space = openmc.stats.SphericalIndependent(source_distance, costheta_angle, phi_angle, origin=(0.0, 0.0, 0.0))
    sett.source = sphere_source
    return sett

# %%
#now create a tally to calibrate the detector
def tallies_func():
    tallies = openmc.Tallies()
    neutron_particle_filter = openmc.ParticleFilter(['neutron'])
    energies = np.logspace(-4, 8, 300)
    energy_filter = openmc.EnergyFilter(energies)
    detector_cell_filter = openmc.CellFilter(detector_cell)
    detector_tally = openmc.Tally(name='detector_tally')
    detector_tally.scores = ['flux']
    detector_tally.filters = [detector_cell_filter, neutron_particle_filter, energy_filter]
    tallies.append(detector_tally)
    #inelastic (n,alpha) reaction between neutrons and 10B
    detector_n_alpha_tally = openmc.Tally(name='detector_n_alpha_tally')
    detector_n_alpha_tally.scores = ['(n,a)']
    detector_n_alpha_tally.filters = [detector_cell_filter, neutron_particle_filter]
    detector_n_alpha_tally.nuclides = ["B10"]
    tallies.append(detector_n_alpha_tally)
    return tallies
tallies = tallies_func()

# %%
energies = np.logspace(-4,7.3,50)
energies
# Out:
# array([1.00000000e-04, 1.70063943e-04, 2.89217448e-04, 4.91854597e-04,
#        8.36467323e-04, 1.42252931e-03, 2.41920945e-03, 4.11420298e-03,
#        6.99677582e-03, 1.18989929e-02, 2.02358965e-02, 3.44139635e-02,
#        5.85257434e-02, 9.95311870e-02, 1.69266662e-01, 2.87861559e-01,
#        4.89548719e-01, 8.32545856e-01, 1.41586031e+00, 2.40786788e+00,
#        4.09491506e+00, 6.96397403e+00, 1.18432088e+01, 2.01410280e+01,
#        3.42526264e+01, 5.82513671e+01, 9.90645720e+01, 1.68473117e+02,
#        2.86512027e+02, 4.87253651e+02, 8.28642773e+02, 1.40922258e+03,
#        2.39657948e+03, 4.07571757e+03, 6.93132602e+03, 1.17876863e+04,
#        2.00466042e+04, 3.40920456e+04, 5.79782772e+04, 9.86001444e+04,
#        1.67683294e+05, 2.85168821e+05, 4.84969343e+05, 8.24757988e+05,
#        1.40261596e+06, 2.38534401e+06, 4.05661008e+06, 6.89883106e+06,
#        1.17324241e+07, 1.99526231e+07])

# %%
nalpha_mean = []
nalpha_std = []
fluxes_mean = []
fluxes_std = []
for energy in energies:
    sett = sett_func(energy)
    model = openmc.model.Model(geometry, materials, sett, tallies)
    # remove old files and runs OpenMC
    # !rm *.h5
    results_filename = model.run()
    results = openmc.StatePoint(results_filename)
    n_alpha_tally = results.get_tally(name="detector_n_alpha_tally")
    flux_tally = results.get_tally(name="detector_tally")
    nalpha_mean.append(n_alpha_tally.mean.ravel())
    fluxes_mean.append(flux_tally.mean.ravel())
    nalpha_std.append(n_alpha_tally.std_dev.ravel())
    fluxes_std.append(flux_tally.std_dev.ravel())
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:34:37
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1495e+00 seconds
#    Reading cross sections          = 1.1226e+00 seconds
#  Total time in simulation          = 8.1014e+00 seconds
#    Time in transport only          = 8.0896e+00 seconds
#    Time in active batches          = 8.1014e+00 seconds
#    Time accumulating tallies       = 5.5896e-03 seconds
#    Time writing statepoints        = 4.5857e-03 seconds
#  Total time for finalization       = 6.8650e-04 seconds
#  Total time elapsed                = 9.2587e+00 seconds
#  Calculation Rate (active)         = 617177 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99344 +/- 0.00003
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:34:47
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0349e+00 seconds
#    Reading cross sections          = 1.0114e+00 seconds
#  Total time in simulation          = 7.8059e+00 seconds
#    Time in transport only          = 7.7913e+00 seconds
#    Time in active batches          = 7.8059e+00 seconds
#    Time accumulating tallies       = 8.7127e-03 seconds
#    Time writing statepoints        = 4.4979e-03 seconds
#  Total time for finalization       = 6.2170e-04 seconds
#  Total time elapsed                = 8.8484e+00 seconds
#  Calculation Rate (active)         = 640543 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99328 +/- 0.00003
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:34:56
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0820e+00 seconds
#    Reading cross sections          = 1.0555e+00 seconds
#  Total time in simulation          = 7.5943e+00 seconds
#    Time in transport only          = 7.5871e+00 seconds
#    Time in active batches          = 7.5943e+00 seconds
#    Time accumulating tallies       = 1.0350e-03 seconds
#    Time writing statepoints        = 4.3213e-03 seconds
#  Total time for finalization       = 6.5950e-04 seconds
#  Total time elapsed                = 8.6840e+00 seconds
#  Calculation Rate (active)         = 658388 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99308 +/- 0.00002
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:35:06
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0744e+00 seconds
#    Reading cross sections          = 1.0529e+00 seconds
#  Total time in simulation          = 7.7066e+00 seconds
#    Time in transport only          = 7.7009e+00 seconds
#    Time in active batches          = 7.7066e+00 seconds
#    Time accumulating tallies       = 1.9340e-04 seconds
#    Time writing statepoints        = 4.2767e-03 seconds
#  Total time for finalization       = 6.2570e-04 seconds
#  Total time elapsed                = 8.7886e+00 seconds
#  Calculation Rate (active)         = 648796 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99295 +/- 0.00001
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:35:15
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0741e+00 seconds
#    Reading cross sections          = 1.0508e+00 seconds
#  Total time in simulation          = 7.3427e+00 seconds
#    Time in transport only          = 7.3372e+00 seconds
#    Time in active batches          = 7.3427e+00 seconds
#    Time accumulating tallies       = 2.8500e-04 seconds
#    Time writing statepoints        = 4.2880e-03 seconds
#  Total time for finalization       = 7.3210e-04 seconds
#  Total time elapsed                = 8.4246e+00 seconds
#  Calculation Rate (active)         = 680946 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99280 +/- 0.00002
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:35:24
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0829e+00 seconds
#    Reading cross sections          = 1.0619e+00 seconds
#  Total time in simulation          = 7.4641e+00 seconds
#    Time in transport only          = 7.4554e+00 seconds
#    Time in active batches          = 7.4641e+00 seconds
#    Time accumulating tallies       = 3.2845e-03 seconds
#    Time writing statepoints        = 4.4255e-03 seconds
#  Total time for finalization       = 6.1810e-04 seconds
#  Total time elapsed                = 8.5547e+00 seconds
#  Calculation Rate (active)         = 669875 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99270 +/- 0.00002
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:35:33
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0911e+00 seconds
#    Reading cross sections          = 1.0675e+00 seconds
#  Total time in simulation          = 7.7907e+00 seconds
#    Time in transport only          = 7.7774e+00 seconds
#    Time in active batches          = 7.7907e+00 seconds
#    Time accumulating tallies       = 7.2926e-03 seconds
#    Time writing statepoints        = 4.5612e-03 seconds
#  Total time for finalization       = 6.3810e-04 seconds
#  Total time elapsed                = 8.8899e+00 seconds
#  Calculation Rate (active)         = 641787 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99267 +/- 0.00003
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:35:43
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0667e+00 seconds
#    Reading cross sections          = 1.0453e+00 seconds
#  Total time in simulation          = 7.4837e+00 seconds
#    Time in transport only          = 7.4724e+00 seconds
#    Time in active batches          = 7.4837e+00 seconds
#    Time accumulating tallies       = 4.9623e-03 seconds
#    Time writing statepoints        = 4.7424e-03 seconds
#  Total time for finalization       = 6.5480e-04 seconds
#  Total time elapsed                = 8.5582e+00 seconds
#  Calculation Rate (active)         = 668120 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99257 +/- 0.00003
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:35:52
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0668e+00 seconds
#    Reading cross sections          = 1.0413e+00 seconds
#  Total time in simulation          = 8.0621e+00 seconds
#    Time in transport only          = 8.0541e+00 seconds
#    Time in active batches          = 8.0621e+00 seconds
#    Time accumulating tallies       = 2.3795e-03 seconds
#    Time writing statepoints        = 4.1995e-03 seconds
#  Total time for finalization       = 6.2080e-04 seconds
#  Total time elapsed                = 9.1366e+00 seconds
#  Calculation Rate (active)         = 620182 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99245 +/- 0.00002
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:36:02
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2106e+00 seconds
#    Reading cross sections          = 1.1808e+00 seconds
#  Total time in simulation          = 8.5201e+00 seconds
#    Time in transport only          = 8.5083e+00 seconds
#    Time in active batches          = 8.5201e+00 seconds
#    Time accumulating tallies       = 7.1108e-03 seconds
#    Time writing statepoints        = 4.3226e-03 seconds
#  Total time for finalization       = 6.4950e-04 seconds
#  Total time elapsed                = 9.7383e+00 seconds
#  Calculation Rate (active)         = 586849 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99237 +/- 0.00002
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:36:12
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0551e+00 seconds
#    Reading cross sections          = 1.0339e+00 seconds
#  Total time in simulation          = 8.1214e+00 seconds
#    Time in transport only          = 8.1066e+00 seconds
#    Time in active batches          = 8.1214e+00 seconds
#    Time accumulating tallies       = 7.4490e-03 seconds
#    Time writing statepoints        = 6.4226e-03 seconds
#  Total time for finalization       = 6.3670e-04 seconds
#  Total time elapsed                = 9.1840e+00 seconds
#  Calculation Rate (active)         = 615655 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 0.99228 +/- 0.00003
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:36:22
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
# ...
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:42:42
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4750e+00 seconds
#    Reading cross sections          = 1.4231e+00 seconds
#  Total time in simulation          = 1.1872e+01 seconds
#    Time in transport only          = 1.1853e+01 seconds
#    Time in active batches          = 1.1872e+01 seconds
#    Time accumulating tallies       = 1.0942e-02 seconds
#    Time writing statepoints        = 6.9521e-03 seconds
#  Total time for finalization       = 1.1784e-03 seconds
#  Total time elapsed                = 1.3366e+01 seconds
#  Calculation Rate (active)         = 421151 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:42:56
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3144e+00 seconds
#    Reading cross sections          = 1.2800e+00 seconds
#  Total time in simulation          = 7.7933e+00 seconds
#    Time in transport only          = 7.7856e+00 seconds
#    Time in active batches          = 7.7933e+00 seconds
#    Time accumulating tallies       = 1.3077e-03 seconds
#    Time writing statepoints        = 4.4465e-03 seconds
#  Total time for finalization       = 6.3410e-04 seconds
#  Total time elapsed                = 9.1159e+00 seconds
#  Calculation Rate (active)         = 641579 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:43:05
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1485e+00 seconds
#    Reading cross sections          = 1.1201e+00 seconds
#  Total time in simulation          = 8.2341e+00 seconds
#    Time in transport only          = 8.2254e+00 seconds
#    Time in active batches          = 8.2341e+00 seconds
#    Time accumulating tallies       = 2.1722e-03 seconds
#    Time writing statepoints        = 4.5783e-03 seconds
#  Total time for finalization       = 6.0940e-04 seconds
#  Total time elapsed                = 9.3904e+00 seconds
#  Calculation Rate (active)         = 607231 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00005 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2022 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.1
#         Git SHA1 | 33bc948f4b855c037975f16d16091fe4ecd12de3
#        Date/Time | 2022-10-11 10:43:16
#    MPI Processes | 1
#   OpenMP Threads | 8
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading Pb204 from /root/nndc_hdf5/Pb204.h5
#  Reading Pb206 from /root/nndc_hdf5/Pb206.h5
#  Reading Pb207 from /root/nndc_hdf5/Pb207.h5
#  Reading Pb208 from /root/nndc_hdf5/Pb208.h5
#  Reading Al27 from /root/nndc_hdf5/Al27.h5
#  Reading Cd106 from /root/nndc_hdf5/Cd106.h5
#  WARNING: Negative value(s) found on probability table for nuclide Cd106 at 294K
#  Reading Cd108 from /root/nndc_hdf5/Cd108.h5
#  Reading Cd110 from /root/nndc_hdf5/Cd110.h5
#  Reading Cd111 from /root/nndc_hdf5/Cd111.h5
#  Reading Cd112 from /root/nndc_hdf5/Cd112.h5
#  Reading Cd113 from /root/nndc_hdf5/Cd113.h5
#  Reading Cd114 from /root/nndc_hdf5/Cd114.h5
#  Reading Cd116 from /root/nndc_hdf5/Cd116.h5
#  Reading B10 from /root/nndc_hdf5/B10.h5
#  Reading B11 from /root/nndc_hdf5/B11.h5
#  Reading F19 from /root/nndc_hdf5/F19.h5
#  Reading C0 from /root/nndc_hdf5/C0.h5
#  Reading H1 from /root/nndc_hdf5/H1.h5
#  Reading H2 from /root/nndc_hdf5/H2.h5
#  Reading c_Al27 from /root/nndc_hdf5/c_Al27.h5
#  Reading c_H_in_CH2 from /root/nndc_hdf5/c_H_in_CH2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for Cd106
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Simulating batch 2
#  Simulating batch 3
#  Simulating batch 4
#  Simulating batch 5
#  Creating state point statepoint.5.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0816e+00 seconds
#    Reading cross sections          = 1.0545e+00 seconds
#  Total time in simulation          = 7.8708e+00 seconds
#    Time in transport only          = 7.8642e+00 seconds
#    Time in active batches          = 7.8708e+00 seconds
#    Time accumulating tallies       = 5.5280e-04 seconds
#    Time writing statepoints        = 4.5577e-03 seconds
#  Total time for finalization       = 6.4690e-04 seconds
#  Total time elapsed                = 8.9602e+00 seconds
#  Calculation Rate (active)         = 635261 particles/second
#
#  ============================>     RESULTS     <============================
#
#  Leakage Fraction            = 1.00013 +/- 0.00001

# %%
    sett = sett_func(energies[0])
    model = openmc.model.Model(geometry, materials, sett, tallies)
    # !rm *.h5
    results_filename = model.run()
    results = openmc.StatePoint(results_filename)
    n_alpha_tally = results.get_tally(name="detector_n_alpha_tally")
    flux_tally = results.get_tally(name="detector_tally")

# %%
std =  n_alpha_tally.std_dev.ravel()

norm_counts = np.concatenate(nalpha_mean).tolist()

#for i, a in enumerate(norm_counts):
   # norm_counts[i] =  1 /a
plt.loglog(energies, norm_counts, color='r', marker='x')
plt.ylabel(r'(n, $\alpha $) reaction rate per particle')
plt.xlabel("Energy (MeV)")
plt.show()
